# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
fig

# %%
fig = plt.figure(figsize=(19.2, 10.8))

# %%
fig =plt.figure()
ax = fig.add_subplot(1, 1, 1)

# %%
ax.set_title('Aquí va el titulo')
fig

# %%
fig = plt.figure()
for i in range(1, 5):
  ax = fig.add_subplot(2,2,i)

# %%
x = np.linspace(0,10,100)
y = np.sin(2*x)

fig = plt.figure()

ax = fig.add_subplot(1,1,1)

ax.set_title('Función sin(2x)')

ax.plot(x,y)

# %%
x = np.linspace(0,10,100)
y = np.sin(2*x)

fig, ax = plt.subplots()

ax.set_title('Función sin(2x)')

ax.plot(x,y)

# %%
ax.set_xlabel('Etiqueta para el eje X')
ax.set_ylabel('Etiqueta para el eje Y')
fig

# %%
ax.grid(True)
fig

# %%
ax.grid()
fig

# %%
x = np.linspace(0,2 * np.pi)
sin = np.sin(x)
cos = np.cos(x)

fig, ax = plt.subplots()

ax.plot(x, sin)
ax.plot(x, cos);

# %%
fig, ax = plt.subplots()
ax.plot(x, sin, label='sin')
ax.plot(x, cos, label='cos')
ax.legend()
fig;

# %%
fig, ax = plt.subplots()
ax.plot(x, sin, label='$f_1(x) = sin(x)$')
ax.plot(x, cos, label='$f_2(x) = cos(x)$')
ax.legend()
fig;

# %%
ax.legend(loc='upper center')
fig

# %%
fig, ax = plt.subplots()

sin_style = dict(linewidth=5, color='darkorange')
cos_style = dict(marker='o', markerfacecolor='limegreen', color ='darkgreen')

ax.plot(x, sin, label='$f_1(x) = sin(x)$', **sin_style)
ax.plot(x, cos, label='$f_2(x) = cos(x)$', **cos_style)
ax.legend()
fig;

# %%
ax.set_xlim(0, np.pi/2)
ax.set_ylim(0,1)
fig

# %%
xsol = np.pi / 4 + np.pi * 0
ysol = np.sin(xsol)
xsol, ysol
# Out:
# (0.7853981633974483, np.float64(0.7071067811865475))

# %%
#Figura
fig, ax = plt.subplots()
ax.plot(x, sin, label='$f_1(x) = sin(x)$')
ax.plot(x, cos, label='$f_2(x) = cos(x)$')
ax.set_xlim(0, np.pi/2)
ax.set_ylim(0,1)

#Flecha
ax.annotate('$sin(x) = cos(x)$',
            xy=(xsol, ysol),
            xytext=(1.2, 0.8), #posicion de la flecha
            arrowprops=dict(facecolor='black', shrink=0.05)) #estilo de la flecha

#Texto que indica el punto de corte
ax.text(0.5, 0.75, '(0.79, 0.71)') #posición del texto y despúes el texto

ax.plot([xsol, xsol], [0, ysol], color='gray', linestyle='--')
ax.plot([0, xsol], [ysol, ysol], color='gray', linestyle='--')

# %%
x = 0.5 + np.arange(5)
y = np.random.uniform(2, 7, len(x))

fig, ax = plt.subplots(figsize=(8, 5))

ax.bar(x,y, width=1, edgecolor ='white', linewidth=0.7)

print('x1', x)
print('y1', y)
plt.show()
# Out:
# x1 [0.5 1.5 2.5 3.5 4.5]
# y1 [2.83964221 2.76417254 2.00548903 2.16984801 2.84927918]

# %%
ax.set_title('Grafico de barras')

xlabvels=['1ra categoría', '2da categoría', '3ra categoría', '4ta categoría', '5ta categoría']
ax.set_xticks(x)
ax.set_xticklabels(xlabvels, rotation=90)
fig

# %%
x = 4 + np.random.normal(0, 1.5, 200)

fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor ='white')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,8))
#bins: intervalos
#rwidth= ancho
#alpha= transparencia
ax.hist(x, bins=14, rwidth=0.95, color='deeppink', alpha=0.2)
plt.show()

# %%
n = 5000
mean_mu1 = 60
sd_sigma1 = 15
data1 = np.random.normal(mean_mu1, sd_sigma1, n)

mean_mu2 = 80
sd_sigma2 = 15
data2 = np.random.normal(mean_mu2, sd_sigma2, n)

# %%
plt.figure(figsize=(8,6))

plt.hist(data1, bins=100, alpha=0.5, label='data1')
plt.hist(data2, bins=100, alpha=0.5, label='data2')

plt.xlabel('Data', size=14)
plt.ylabel('Count', size =14)
plt.title('Multiple Histograms with Matplotlib')
plt.legend(loc='upper right')

plt.show()

# %%
data = np.random.normal(3,5,4)

fig, ax = plt.subplots(figsize=(15,8))
ax.set_title('Basic Plot')
ax.boxplot(data)
plt.show()

# %%
#Horizontal
fig2, ax2 = plt.subplots(figsize=(15,8))
ax2.set_title('Notched Boxes')
ax2.boxplot(data, vert=False)
plt.show()

# %%
#(medias, desviaciones, tamaño)
D = np.random.normal((3,5,4), (1.25, 1.00, 1.25), (100,3))
np.shape(D)
# Out:
# (100, 3)

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.boxplot(D, positions=[2,4,6], widths=1.5)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.boxplot(D, positions=[2,4,6], widths=1.5, patch_artist=True,
           showmeans=False, showfliers=True,
           flierprops={'color':'black', 'markerfacecolor': 'cyan', 'markersize': 9},
           medianprops={'color': 'white', 'linewidth': 1.5},
           boxprops={'facecolor': 'pink', 'edgecolor':'white', 'linewidth': 0.5},
           whiskerprops={'color': 'magenta', 'linewidth': 2.5},
           capprops={'color': 'green', 'linewidth': 3.5})
plt.show()

# %%
n = 200

mean_mu1 = 60
sd_sigma1 = 15
x = np.random.normal(mean_mu1, sd_sigma1, n)

y = 2*x + np.random.normal(5,4,n)

# %%
fig, ax = plt.subplots(figsize=(12,9))
ax.scatter(x,y,
           s = 40, #tamaño de los puntos
           color= 'green',
           alpha = 0.7, #Transparencia
           edgecolors='none')

plt.xlabel('x', size=14)
plt.ylabel('y', size=14)
plt.title('Scatter Plot with Matplotlib')
plt.show()

# %%
a = np.array([[1,1,2,2,3],
              [2,2,3,3,5],
              [1,4,2,2,3]])
a
# Out:
# array([[1, 1, 2, 2, 3],
#        [2, 2, 3, 3, 5],
#        [1, 4, 2, 2, 3]])

# %%
mcor = np.corrcoef(a)
mcor
# Out:
# array([[1.        , 0.97590007, 0.10482848],
#        [0.97590007, 1.        , 0.17902872],
#        [0.10482848, 0.17902872, 1.        ]])

# %%
fig, ax = plt.subplots()
im = ax.imshow(mcor, cmap='Reds')
fig.colorbar(im, ax=ax, label='Coorelaciones')
plt.show()

# %%
import seaborn as sns

# %%
sns.set_theme(style='darkgrid')

tips = sns.load_dataset('tips')
g = sns.jointplot(x='total_bill', y='tip', data=tips,
                  kind='scatter', #scatter,kde,hist,hex,reg,resid
                  xlim=(0, 60), ylim=(0,12),
                  color='m', height=7)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset('tips')
g = sns.jointplot(x='total_bill', y='tip', data=tips,
                  kind='reg',
                  xlim=(0, 60), ylim=(0,12),
                  color='m', height=7)

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.pairplot(df) #solo variables numericas

# %%
df = sns.load_dataset('penguins')
sns.pairplot(df, hue='species')

# %%
#Figura de escala logaritmica
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale('log')


planets = sns.load_dataset('planets')

#Boxplot
sns.boxplot(x='distance', y='method', data=planets,
            whis=[0,100], width=.6, palette='vlag')

#Añadir puntos de datos
sns.stripplot(x='distance', y='method', data=planets,
              size=4, color='.3', linewidth=0)

#Configuración visual
ax.xaxis.grid(True)
ax.set(ylabel='')
sns.despine(trim=True, left=True)
# Out:
# /tmp/ipykernel_1412/3260182161.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='distance', y='method', data=planets,

# %%
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot(index='month', columns='year', values='passengers')
ax = sns.heatmap(flights)

# %%
ax = sns.heatmap(flights, annot=True, fmt='d', linewidths=.5, cmap='YlGnBu')

# %%
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
fig, ax =plt.subplots(figsize=(10,10))
ax = sns.heatmap(flights.corr(), cmap='YlGnBu', annot=True)
