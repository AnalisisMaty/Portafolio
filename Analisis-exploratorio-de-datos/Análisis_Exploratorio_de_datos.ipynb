# %%
#Librerías:

#YData Profiling
#SweetViz
#Missingno
#Sketch

# %%
# !pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 59.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv('Xeek_Well_15-9-15.csv')
df
# Out:
#           WELL  DEPTH_MD         GROUP      FORMATION      CALI      RDEP  \
# 0      15/9-15   485.256  NORDLAND GP.            NaN       NaN  1.735962
# 1      15/9-15   485.408  NORDLAND GP.            NaN       NaN  1.744778
# 2      15/9-15   485.560  NORDLAND GP.            NaN       NaN  1.752990
# 3      15/9-15   485.712  NORDLAND GP.            NaN       NaN  1.760675
# 4      15/9-15   485.864  NORDLAND GP.            NaN       NaN  1.767360
# ...        ...       ...           ...            ...       ...       ...
# 17712  15/9-15  3199.520     HEGRE GP.  Skagerrak Fm.  7.776711  0.862399
# 17713  15/9-15  3199.672     HEGRE GP.  Skagerrak Fm.  7.779644  0.847839
# 17714  15/9-15  3199.824     HEGRE GP.  Skagerrak Fm.  7.792982  0.844712
# 17715  15/9-15  3199.976     HEGRE GP.  Skagerrak Fm.       NaN  0.839559
# 17716  15/9-15  3200.128     HEGRE GP.  Skagerrak Fm.       NaN  0.828312
#
#            RHOB         GR      NPHI        PEF         DTC       LITH
# ...

# %%
ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.18.4&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-07-27 22:55:16.244930&quot; name=date&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
profile = ProfileReport(df, title="Reporte de Perfilado - Xeek Well 15-9-15")
profile.to_file("reporte_xeek_well.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install dtale
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 67.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 105.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.0/204.0 kB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 53.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.6/495.6 kB 33.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

df = pd.read_csv('Xeek_Well_15-9-15.csv')

# %%
import dtale as dt
import dtale.app as dtale_app

dtale_app.USE_COLAB = True

#si esto se usa en jupiter notebook debería funcionar sin
#dtale_app.USE_COLAB = True
#si hay problemas probar:
#dtale.show(df, host='local host')

# %%
dt.show(df)
# Out:
# https://40000-m-s-kkb-usw1b0-1amshoyck0znw-b.us-west1-0.prod.colab.dev/dtale/main/5

# %%
# !pip install SweetViz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 39.8 MB/s eta 0:00:00
# ...

# %%
import sweetviz as sv
import pandas as pd

df = pd.read_csv('Xeek_Well_15-9-15.csv')

# %%
report = sv.analyze(df)
report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# !pip install missingno

# %%
import pandas as pd
import missingno as msno

df = pd.read_csv('Xeek_Well_15-9-15.csv')

# %%
msno.bar(df)
msno.matrix(df)
msno.dendrogram(df)
msno.heatmap(df)
# Out:
# <Axes: >

# %%
# !pip install sketch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 748.4/748.4 kB 28.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 84.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.9 MB/s eta 0:00:00
# ...

# %%
import sketch
import pandas as pd

df = pd.read_csv('Xeek_Well_15-9-15.csv')

# %%
import os

# 1. Indícale a sketch que NO use el servidor remoto por defecto
os.environ["SKETCH_USE_REMOTE_LAMBDAPROMPT"] = "False"

# 2. Asigna tu API Key de OpenAI (reemplaza con tu clave real)
os.environ["OPENAI_API_KEY"] = "sk-proj-tu-api-key-aqui..."

# %%
df.sketch.ask('What are the max values of each numerical column?')
# Out:
# ---------------------------------------------------------------------------
# ContentTypeError                          Traceback (most recent call last)
# /tmp/ipykernel_11453/2364160286.py in <cell line: 0>()
# ----> 1 df.sketch.ask('What are the max values of each numerical column?')
#
# /usr/local/lib/python3.12/dist-packages/sketch/pandas_extension.py in ask(self, question, call_display)
#     328
#     329     def ask(self, question, call_display=True):
# --> 330         result = call_prompt_on_dataframe(self._obj, ask_from_parts, question=question)
#     331         if not call_display:
#     332             return result
#
# /usr/local/lib/python3.12/dist-packages/sketch/pandas_extension.py in call_prompt_on_dataframe(df, prompt, **kwargs)
#     178     else:
#     179         # using local version
# --> 180         text_to_copy = prompt(**prompt_kwargs)
#     181     return text_to_copy
#     182
#
# ...
